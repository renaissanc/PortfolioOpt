# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import scipy.stats

# %%
ticker_symbol = 'AAPL'
AAPL = yf.download(ticker_symbol, start = '2022-01-01', end = '2022-12-31')
#AAPL = pd.DataFrame(stock_data)

ticker_symbol = 'MSFT'
MSFT = yf.download(ticker_symbol, start = '2022-01-01', end = '2022-12-31')
#MSFT = pd.DataFrame(stock_data)

ticker_symbol = 'JPM'
JPM = yf.download(ticker_symbol, start = '2022-01-01', end = '2022-12-31')
#JPM = pd.DataFrame(stock_data)

ticker_symbol = 'TSLA'
TSLA = yf.download(ticker_symbol, start = '2022-01-01', end = '2022-12-31')
#TSLA = pd.DataFrame(stock_data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
AAPL
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  179.273605
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  176.998322
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  172.290176
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  169.414093
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  169.581558
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  130.631378
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  128.818405
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  124.865593
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  128.402313
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  128.719330
#
#                Volume
# Date
# 2022-01-03  104487900
# 2022-01-04   99310400
# 2022-01-05   94537600
# 2022-01-06   96904000
# 2022-01-07   86709100
# ...               ...
# 2022-12-23   63814900
# 2022-12-27   69007800
# 2022-12-28   85438400
# 2022-12-29   75703700
# 2022-12-30   77034200
#
# [251 rows x 6 columns]

# %%
MSFT
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  335.350006  338.000000  329.779999  334.750000  326.940826
# 2022-01-04  334.829987  335.200012  326.119995  329.010010  321.334778
# 2022-01-05  325.859985  326.070007  315.980011  316.380005  308.999359
# 2022-01-06  313.149994  318.700012  311.489990  313.880005  306.557678
# 2022-01-07  314.149994  316.500000  310.089996  314.040009  306.713989
# ...                ...         ...         ...         ...         ...
# 2022-12-23  236.110001  238.869995  233.940002  238.729996  235.345581
# 2022-12-27  238.699997  238.929993  235.830002  236.960007  233.600647
# 2022-12-28  236.889999  239.720001  234.169998  234.529999  231.205109
# 2022-12-29  235.649994  241.919998  235.649994  241.009995  237.593246
# 2022-12-30  238.210007  239.960007  236.660004  239.820007  236.420135
#
#               Volume
# Date
# 2022-01-03  28865100
# 2022-01-04  32674300
# 2022-01-05  40054300
# 2022-01-06  39646100
# 2022-01-07  32720000
# ...              ...
# 2022-12-23  21207000
# 2022-12-27  16688600
# 2022-12-28  17457100
# 2022-12-29  19770700
# 2022-12-30  21938500
#
# [251 rows x 6 columns]

# %%
JPM
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  159.860001  162.639999  159.509995  161.699997  149.576157
# 2022-01-04  164.309998  168.580002  164.229996  167.830002  155.246521
# 2022-01-05  167.820007  168.360001  163.729996  163.779999  152.408264
# 2022-01-06  166.910004  167.369995  163.869995  165.520004  154.027466
# 2022-01-07  165.669998  167.529999  165.059998  167.160004  155.553604
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.580002  131.440002  129.639999  131.279999  125.269859
# 2022-12-27  131.570007  132.220001  130.550003  131.740005  125.708817
# 2022-12-28  131.850006  133.410004  131.009995  132.460007  126.395836
# 2022-12-29  132.929993  133.270004  132.309998  133.220001  127.121048
# 2022-12-30  132.809998  134.330002  132.440002  134.100006  127.960762
#
#               Volume
# Date
# 2022-01-03  13120900
# 2022-01-04  20195800
# 2022-01-05  17539400
# 2022-01-06  14047500
# 2022-01-07  13913300
# ...              ...
# 2022-12-23   5091900
# 2022-12-27   5411000
# 2022-12-28   8827700
# 2022-12-29   6585200
# 2022-12-30   9292500
#
# [251 rows x 6 columns]

# %%
TSLA
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  382.583344  400.356659  378.679993  399.926666  399.926666
# 2022-01-04  396.516663  402.666656  374.350006  383.196655  383.196655
# 2022-01-05  382.216675  390.113342  360.336670  362.706665  362.706665
# 2022-01-06  359.000000  362.666656  340.166656  354.899994  354.899994
# 2022-01-07  360.123322  360.309998  336.666656  342.320007  342.320007
# ...                ...         ...         ...         ...         ...
# 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#                Volume
# Date
# 2022-01-03  103931400
# 2022-01-04  100248300
# 2022-01-05   80119800
# 2022-01-06   90336600
# 2022-01-07   84164700
# ...               ...
# 2022-12-23  166989700
# 2022-12-27  208643400
# 2022-12-28  221070500
# 2022-12-29  221923300
# 2022-12-30  157777300
#
# [251 rows x 6 columns]

# %%
AAPL = AAPL.drop(columns=['Volume','Open', 'High', 'Low', 'Close'])
MSFT = MSFT.drop(columns=['Volume','Open', 'High', 'Low', 'Close'])
JPM = JPM.drop(columns=['Volume','Open', 'High', 'Low', 'Close'])
TSLA = TSLA.drop(columns=['Volume','Open', 'High', 'Low', 'Close'])

# %%
AAPL
# Out:
#              Adj Close
# Date
# 2022-01-03  179.273605
# 2022-01-04  176.998322
# 2022-01-05  172.290176
# 2022-01-06  169.414093
# 2022-01-07  169.581558
# ...                ...
# 2022-12-23  130.631378
# 2022-12-27  128.818405
# 2022-12-28  124.865593
# 2022-12-29  128.402313
# 2022-12-30  128.719330
#
# [251 rows x 1 columns]

# %%
MSFT
# Out:
#              Adj Close
# Date
# 2022-01-03  326.940826
# 2022-01-04  321.334778
# 2022-01-05  308.999359
# 2022-01-06  306.557678
# 2022-01-07  306.713989
# ...                ...
# 2022-12-23  235.345581
# 2022-12-27  233.600647
# 2022-12-28  231.205109
# 2022-12-29  237.593246
# 2022-12-30  236.420135
#
# [251 rows x 1 columns]

# %%
JPM
# Out:
#              Adj Close
# Date
# 2022-01-03  149.576157
# 2022-01-04  155.246521
# 2022-01-05  152.408264
# 2022-01-06  154.027466
# 2022-01-07  155.553604
# ...                ...
# 2022-12-23  125.269859
# 2022-12-27  125.708817
# 2022-12-28  126.395836
# 2022-12-29  127.121048
# 2022-12-30  127.960762
#
# [251 rows x 1 columns]

# %%
TSLA
# Out:
#              Adj Close
# Date
# 2022-01-03  399.926666
# 2022-01-04  383.196655
# 2022-01-05  362.706665
# 2022-01-06  354.899994
# 2022-01-07  342.320007
# ...                ...
# 2022-12-23  123.150002
# 2022-12-27  109.099998
# 2022-12-28  112.709999
# 2022-12-29  121.820000
# 2022-12-30  123.180000
#
# [251 rows x 1 columns]

# %%
plt.style.use('dark_background')
fig, ax = plt.subplots()

ax.plot(AAPL['Adj Close'], label='AAPL')
ax.plot(MSFT['Adj Close'], label='MSFT')
ax.plot(JPM['Adj Close'], label='JPM')
ax.plot(TSLA['Adj Close'], label='TSLA')

fig.patch.set_facecolor('#1e1e1e')
ax.set_facecolor('#2b2b2b')

ax.grid(color='gray', linestyle='--', linewidth=0.5)

ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')

ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

ax.set_xlabel('Time Series', color='white')
ax.set_ylabel('Price', color='white')
ax.set_title('Plotting Price Charts', color='white')

legend = ax.legend()
frame = legend.get_frame()
frame.set_facecolor('#1e1e1e')  # Set the legend background color
frame.set_edgecolor('white')  # Set the legend border color
for text in legend.get_texts():
    text.set_color('white')  # Set the legend text color

ax.axis('auto')
plt.show()

# %%
AAPL['Pct_Change'] = AAPL['Adj Close'].pct_change() * 100
MSFT['Pct_Change'] = MSFT['Adj Close'].pct_change() * 100
JPM['Pct_Change'] = JPM['Adj Close'].pct_change() * 100
TSLA['Pct_Change'] = TSLA['Adj Close'].pct_change() * 100

# %%
AAPL
# Out:
#              Adj Close  Pct_Change
# Date
# 2022-01-03  179.273605         NaN
# 2022-01-04  176.998322   -1.269168
# 2022-01-05  172.290176   -2.659994
# 2022-01-06  169.414093   -1.669325
# 2022-01-07  169.581558    0.098850
# ...                ...         ...
# 2022-12-23  130.631378   -0.279799
# 2022-12-27  128.818405   -1.387854
# 2022-12-28  124.865593   -3.068515
# 2022-12-29  128.402313    2.832422
# 2022-12-30  128.719330    0.246893
#
# [251 rows x 2 columns]

# %%
MSFT
# Out:
#              Adj Close  Pct_Change
# Date
# 2022-01-03  326.940826         NaN
# 2022-01-04  321.334778   -1.714698
# 2022-01-05  308.999359   -3.838806
# 2022-01-06  306.557678   -0.790190
# 2022-01-07  306.713989    0.050989
# ...                ...         ...
# 2022-12-23  235.345581    0.226712
# 2022-12-27  233.600647   -0.741435
# 2022-12-28  231.205109   -1.025484
# 2022-12-29  237.593246    2.762974
# 2022-12-30  236.420135   -0.493748
#
# [251 rows x 2 columns]

# %%
JPM
# Out:
#              Adj Close  Pct_Change
# Date
# 2022-01-03  149.576157         NaN
# 2022-01-04  155.246521    3.790955
# 2022-01-05  152.408264   -1.828226
# 2022-01-06  154.027466    1.062411
# 2022-01-07  155.553604    0.990822
# ...                ...         ...
# 2022-12-23  125.269859    0.474512
# 2022-12-27  125.708817    0.350409
# 2022-12-28  126.395836    0.546516
# 2022-12-29  127.121048    0.573763
# 2022-12-30  127.960762    0.660563
#
# [251 rows x 2 columns]

# %%
TSLA
# Out:
#              Adj Close  Pct_Change
# Date
# 2022-01-03  399.926666         NaN
# 2022-01-04  383.196655   -4.183270
# 2022-01-05  362.706665   -5.347121
# 2022-01-06  354.899994   -2.152337
# 2022-01-07  342.320007   -3.544657
# ...                ...         ...
# 2022-12-23  123.150002   -1.755083
# 2022-12-27  109.099998  -11.408853
# 2022-12-28  112.709999    3.308892
# 2022-12-29  121.820000    8.082691
# 2022-12-30  123.180000    1.116402
#
# [251 rows x 2 columns]

# %%
fig, ax = plt.subplots()

ax.plot(AAPL['Pct_Change'], label='AAPL')
ax.plot(MSFT['Pct_Change'], label='MSFT')
ax.plot(JPM['Pct_Change'], label='JPM')
ax.plot(TSLA['Pct_Change'], label='TSLA')

fig.patch.set_facecolor('#1e1e1e')
ax.set_facecolor('#2b2b2b')

ax.grid(color='gray', linestyle='--', linewidth=0.5)

# Customize the spines (axis borders)
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')

# Customize the ticks
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

ax.set_xlabel('Time Series', color='white')
ax.set_ylabel('Price', color='white')
ax.set_title('Plotting Price Charts', color='white')

legend = ax.legend()
frame = legend.get_frame()
frame.set_facecolor('#1e1e1e')  # Set the legend background color
frame.set_edgecolor('white')  # Set the legend border color
for text in legend.get_texts():
    text.set_color('white')  # Set the legend text color

ax.axis('auto')

plt.show()

# %%
AAPL['Cumulative_Pct_Change'] = (1 + AAPL['Adj Close'].pct_change()).cumprod() - 1
AAPL['Cumulative_Pct_Change'] = AAPL['Cumulative_Pct_Change'] * 100

MSFT['Cumulative_Pct_Change'] = (1 + MSFT['Adj Close'].pct_change()).cumprod() - 1
MSFT['Cumulative_Pct_Change'] = MSFT['Cumulative_Pct_Change'] * 100

JPM['Cumulative_Pct_Change'] = (1 + JPM['Adj Close'].pct_change()).cumprod() - 1
JPM['Cumulative_Pct_Change'] = JPM['Cumulative_Pct_Change'] * 100

TSLA['Cumulative_Pct_Change'] = (1 + TSLA['Adj Close'].pct_change()).cumprod() - 1
TSLA['Cumulative_Pct_Change'] = TSLA['Cumulative_Pct_Change'] * 100

# %%
AAPL
# Out:
#              Adj Close  Pct_Change  Cumulative_Pct_Change
# Date
# 2022-01-03  179.273605         NaN                    NaN
# 2022-01-04  176.998322   -1.269168              -1.269168
# 2022-01-05  172.290176   -2.659994              -3.895403
# 2022-01-06  169.414093   -1.669325              -5.499701
# 2022-01-07  169.581558    0.098850              -5.406288
# ...                ...         ...                    ...
# 2022-12-23  130.631378   -0.279799             -27.132955
# 2022-12-27  128.818405   -1.387854             -28.144244
# 2022-12-28  124.865593   -3.068515             -30.349148
# 2022-12-29  128.402313    2.832422             -28.376342
# 2022-12-30  128.719330    0.246893             -28.199508
#
# [251 rows x 3 columns]

# %%
MSFT
# Out:
#              Adj Close  Pct_Change  Cumulative_Pct_Change
# Date
# 2022-01-03  326.940826         NaN                    NaN
# 2022-01-04  321.334778   -1.714698              -1.714698
# 2022-01-05  308.999359   -3.838806              -5.487680
# 2022-01-06  306.557678   -0.790190              -6.234507
# 2022-01-07  306.713989    0.050989              -6.186697
# ...                ...         ...                    ...
# 2022-12-23  235.345581    0.226712             -28.015848
# 2022-12-27  233.600647   -0.741435             -28.549564
# 2022-12-28  231.205109   -1.025484             -29.282277
# 2022-12-29  237.593246    2.762974             -27.328364
# 2022-12-30  236.420135   -0.493748             -27.687179
#
# [251 rows x 3 columns]

# %%
JPM
# Out:
#              Adj Close  Pct_Change  Cumulative_Pct_Change
# Date
# 2022-01-03  149.576157         NaN                    NaN
# 2022-01-04  155.246521    3.790955               3.790955
# 2022-01-05  152.408264   -1.828226               1.893422
# 2022-01-06  154.027466    1.062411               2.975948
# 2022-01-07  155.553604    0.990822               3.996257
# ...                ...         ...                    ...
# 2022-12-23  125.269859    0.474512             -16.250115
# 2022-12-27  125.708817    0.350409             -15.956648
# 2022-12-28  126.395836    0.546516             -15.497337
# 2022-12-29  127.121048    0.573763             -15.012492
# 2022-12-30  127.960762    0.660563             -14.451096
#
# [251 rows x 3 columns]

# %%
TSLA
# Out:
#              Adj Close  Pct_Change  Cumulative_Pct_Change
# Date
# 2022-01-03  399.926666         NaN                    NaN
# 2022-01-04  383.196655   -4.183270              -4.183270
# 2022-01-05  362.706665   -5.347121              -9.306707
# 2022-01-06  354.899994   -2.152337             -11.258732
# 2022-01-07  342.320007   -3.544657             -14.404306
# ...                ...         ...                    ...
# 2022-12-23  123.150002   -1.755083             -69.206854
# 2022-12-27  109.099998  -11.408853             -72.719999
# 2022-12-28  112.709999    3.308892             -71.817333
# 2022-12-29  121.820000    8.082691             -69.539416
# 2022-12-30  123.180000    1.116402             -69.199353
#
# [251 rows x 3 columns]

# %%
fig, ax = plt.subplots()

ax.plot(AAPL['Cumulative_Pct_Change'], label='AAPL')
ax.plot(MSFT['Cumulative_Pct_Change'], label='MSFT')
ax.plot(JPM['Cumulative_Pct_Change'], label='JPM')
ax.plot(TSLA['Cumulative_Pct_Change'], label='TSLA')

fig.patch.set_facecolor('#1e1e1e')
ax.set_facecolor('#2b2b2b')

ax.grid(color='gray', linestyle='--', linewidth=0.5)
# Customize the spines (axis borders)
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
# Customize the ticks
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
# Customize the labels and title
ax.set_xlabel('Time Series', color='white')
ax.set_ylabel('Price', color='white')
ax.set_title('Plotting Price Charts', color='white')

# Customize the legend
legend = ax.legend()
frame = legend.get_frame()
frame.set_facecolor('#1e1e1e')  # Set the legend background color
frame.set_edgecolor('white')  # Set the legend border color
for text in legend.get_texts():
    text.set_color('white')  # Set the legend text color
    
ax.axis('auto')

plt.show()

# %%
AAPL = AAPL.dropna()
MSFT = MSFT.dropna()
JPM = JPM.dropna()
TSLA = TSLA.dropna()

# %%
AAPL
# Out:
#              Adj Close  Pct_Change  Cumulative_Pct_Change
# Date
# 2022-01-04  176.998322   -1.269168              -1.269168
# 2022-01-05  172.290176   -2.659994              -3.895403
# 2022-01-06  169.414093   -1.669325              -5.499701
# 2022-01-07  169.581558    0.098850              -5.406288
# 2022-01-10  169.601242    0.011607              -5.395308
# ...                ...         ...                    ...
# 2022-12-23  130.631378   -0.279799             -27.132955
# 2022-12-27  128.818405   -1.387854             -28.144244
# 2022-12-28  124.865593   -3.068515             -30.349148
# 2022-12-29  128.402313    2.832422             -28.376342
# 2022-12-30  128.719330    0.246893             -28.199508
#
# [250 rows x 3 columns]

# %%
MSFT
# Out:
#              Adj Close  Pct_Change  Cumulative_Pct_Change
# Date
# 2022-01-04  321.334778   -1.714698              -1.714698
# 2022-01-05  308.999359   -3.838806              -5.487680
# 2022-01-06  306.557678   -0.790190              -6.234507
# 2022-01-07  306.713989    0.050989              -6.186697
# 2022-01-10  306.938599    0.073231              -6.117996
# ...                ...         ...                    ...
# 2022-12-23  235.345581    0.226712             -28.015848
# 2022-12-27  233.600647   -0.741435             -28.549564
# 2022-12-28  231.205109   -1.025484             -29.282277
# 2022-12-29  237.593246    2.762974             -27.328364
# 2022-12-30  236.420135   -0.493748             -27.687179
#
# [250 rows x 3 columns]

# %%
JPM
# Out:
#              Adj Close  Pct_Change  Cumulative_Pct_Change
# Date
# 2022-01-04  155.246521    3.790955               3.790955
# 2022-01-05  152.408264   -1.828226               1.893422
# 2022-01-06  154.027466    1.062411               2.975948
# 2022-01-07  155.553604    0.990822               3.996257
# 2022-01-10  155.702469    0.095700               4.095781
# ...                ...         ...                    ...
# 2022-12-23  125.269859    0.474512             -16.250115
# 2022-12-27  125.708817    0.350409             -15.956648
# 2022-12-28  126.395836    0.546516             -15.497337
# 2022-12-29  127.121048    0.573763             -15.012492
# 2022-12-30  127.960762    0.660563             -14.451096
#
# [250 rows x 3 columns]

# %%
TSLA
# Out:
#              Adj Close  Pct_Change  Cumulative_Pct_Change
# Date
# 2022-01-04  383.196655   -4.183270              -4.183270
# 2022-01-05  362.706665   -5.347121              -9.306707
# 2022-01-06  354.899994   -2.152337             -11.258732
# 2022-01-07  342.320007   -3.544657             -14.404306
# 2022-01-10  352.706665    3.034195             -11.807165
# ...                ...         ...                    ...
# 2022-12-23  123.150002   -1.755083             -69.206854
# 2022-12-27  109.099998  -11.408853             -72.719999
# 2022-12-28  112.709999    3.308892             -71.817333
# 2022-12-29  121.820000    8.082691             -69.539416
# 2022-12-30  123.180000    1.116402             -69.199353
#
# [250 rows x 3 columns]

# %%
len(AAPL)
# Out:
# 250

# %%
len(MSFT)
# Out:
# 250

# %%
len(JPM)
# Out:
# 250

# %%
len(TSLA)
# Out:
# 250

# %%
AAPL_mean = AAPL['Pct_Change'].mean()
AAPL_median = AAPL['Pct_Change'].median()
AAPL_variance = AAPL['Pct_Change'].var()
AAPL_std_dev = AAPL['Pct_Change'].std()

print(f'AAPL percentage mean: {AAPL_mean}')
print(f'AAPL percentage Median: {AAPL_median}')
print(f'AAPL percentage Variance: {AAPL_variance}')
print(f'AAPL percentage Standard: {AAPL_std_dev} \n')

MSFT_mean = MSFT['Pct_Change'].mean()
MSFT_median = MSFT['Pct_Change'].median()
MSFT_variance = MSFT['Pct_Change'].var()
MSFT_std_dev = MSFT['Pct_Change'].std()

print(f'AAPL percentage mean: {MSFT_mean}')
print(f'AAPL percentage Median: {MSFT_median}')
print(f'AAPL percentage Variance: {MSFT_variance}')
print(f'AAPL percentage Standard: {MSFT_std_dev} \n')

JPM_mean = JPM['Pct_Change'].mean()
JPM_median = JPM['Pct_Change'].median()
JPM_variance = JPM['Pct_Change'].var()
JPM_std_dev = JPM['Pct_Change'].std()

print(f'JPM percentage mean: {JPM_mean}')
print(f'JPM percentage Median: {JPM_median}')
print(f'JPM percentage Variance: {JPM_variance}')
print(f'JPM percentage Standard: {JPM_std_dev} \n')

TSLA_mean = TSLA['Pct_Change'].mean()
TSLA_median = TSLA['Pct_Change'].median()
TSLA_variance = TSLA['Pct_Change'].var()
TSLA_std_dev = TSLA['Pct_Change'].std()

print(f'TSLA percentage mean: {TSLA_mean}')
print(f'TSLA percentage Median: {TSLA_median}')
print(f'TSLA percentage Variance: {TSLA_variance}')
print(f'TSLA percentage Standard: {TSLA_std_dev} \n')
# Out:
# AAPL percentage mean: -0.10735006203032595
# AAPL percentage Median: -0.13600091662701042
# AAPL percentage Variance: 5.049595003667863
# AAPL percentage Standard: 2.2471303931164885
#
# AAPL percentage mean: -0.1048503302270052
# AAPL percentage Median: -0.18334354871221703
# AAPL percentage Variance: 4.967889583617856
# AAPL percentage Standard: 2.2288763051407443
#
# JPM percentage mean: -0.044840054792093964
# JPM percentage Median: -0.11077537850380792
# JPM percentage Variance: 3.5366890762144423
# JPM percentage Standard: 1.8806086983246786
#
# TSLA percentage mean: -0.38474981744944897
# TSLA percentage Median: -0.11457910842563312
# TSLA percentage Variance: 16.93770418113314
# TSLA percentage Standard: 4.115544214454893

# %%
def compute_sharp_ratio(df,risk_free_rate=0):
    mean_return = df['Pct_Change'].mean()
    std = df['Pct_Change'].std()
    
    sharp_ratio = (mean_return - risk_free_rate)/std
    sharp_ratio = sharp_ratio * np.sqrt(252)
    
    return sharp_ratio

# %%
sr_ratio_AAPL = compute_sharp_ratio(AAPL)
sr_ratio_AAPL
# Out:
# -0.7583580416062042

# %%
sr_ratio_MSFT = compute_sharp_ratio(MSFT)
sr_ratio_MSFT
# Out:
# -0.7467652593116076

# %%
sr_ratio_JPM = compute_sharp_ratio(JPM)
sr_ratio_JPM
# Out:
# -0.3785018133546103

# %%
sr_ratio_TSLA = compute_sharp_ratio(TSLA)
sr_ratio_TSLA
# Out:
# -1.484059868009806

# %%
matrix = [sr_ratio_AAPL, sr_ratio_MSFT, sr_ratio_JPM, sr_ratio_TSLA]

# %%
matrix_f = np.array(matrix).reshape(2, 2)

# %%
sns.heatmap(matrix_f, annot=True, cmap='viridis')
plt.title('Heatmap')
plt.show()

# %%
def compute_sortino_ratio(df,risk_free_rate=0,threshold=0):
    mean_return = df['Pct_Change'].mean()
    downside = df[df['Pct_Change']<threshold]['Pct_Change']
    
    std = downside.std()
    
    sortino_ratio = (mean_return - risk_free_rate)/std
    sortino_ratio = sortino_ratio * np.sqrt(252)
    
    return sortino_ratio

# %%
srt_ratio_AAPL = compute_sortino_ratio(AAPL)
srt_ratio_AAPL
# Out:
# -1.2587466221948531

# %%
srt_ratio_MSFT = compute_sortino_ratio(MSFT)
srt_ratio_MSFT
# Out:
# -1.1956645997819437

# %%
srt_ratio_JPM = compute_sortino_ratio(JPM)
srt_ratio_JPM
# Out:
# -0.6395393914526389

# %%
srt_ratio_TSLA = compute_sortino_ratio(TSLA)
srt_ratio_TSLA
# Out:
# -2.158625745587281

# %%
def compute_psr(df,benchmark=0):
    sr = compute_sharp_ratio(df)/np.sqrt(252)
    skew = scipy.stats.skew(df['Pct_Change'])
    kurtosis = scipy.stats.kurtosis(df['Pct_Change'],fisher=True)
    n = len(df)
    
    sigma_sr = ((1/(n-1)) * (1 + 0.5*sr**2 + skew * sr + (kurtosis/4) * sr**2) )**0.5
    ratio = (sr-benchmark)/sigma_sr
    
    psr = scipy.stats.norm.cdf(ratio)
    
    return psr

# %%
compute_psr(AAPL)
# Out:
# 0.2239059668622504

# %%
compute_psr(MSFT)
# Out:
# 0.2283597685187757

# %%
compute_psr(JPM)
# Out:
# 0.35296090494229526

# %%
compute_psr(TSLA)
# Out:
# 0.07184175758895042

# %%
Pure_Pct_Returns = pd.concat([AAPL['Pct_Change'],MSFT['Pct_Change'],JPM['Pct_Change'],TSLA['Pct_Change']],axis=1)
Pure_Pct_Returns.columns = ['AAPL','MSFT','JPM','TSLA']

# %%
Pure_Pct_Returns
# Out:
#                 AAPL      MSFT       JPM       TSLA
# Date
# 2022-01-04 -1.269168 -1.714698  3.790955  -4.183270
# 2022-01-05 -2.659994 -3.838806 -1.828226  -5.347121
# 2022-01-06 -1.669325 -0.790190  1.062411  -2.152337
# 2022-01-07  0.098850  0.050989  0.990822  -3.544657
# 2022-01-10  0.011607  0.073231  0.095700   3.034195
# ...              ...       ...       ...        ...
# 2022-12-23 -0.279799  0.226712  0.474512  -1.755083
# 2022-12-27 -1.387854 -0.741435  0.350409 -11.408853
# 2022-12-28 -3.068515 -1.025484  0.546516   3.308892
# 2022-12-29  2.832422  2.762974  0.573763   8.082691
# 2022-12-30  0.246893 -0.493748  0.660563   1.116402
#
# [250 rows x 4 columns]

# %%
Pure_Returns = pd.concat([AAPL['Adj Close'],MSFT['Adj Close'],JPM['Adj Close'],TSLA['Adj Close']],axis=1)
Pure_Returns.columns = ['AAPL','MSFT','JPM','TSLA']

# %%
Pure_Returns
# Out:
#                   AAPL        MSFT         JPM        TSLA
# Date
# 2022-01-04  176.998322  321.334778  155.246521  383.196655
# 2022-01-05  172.290176  308.999359  152.408264  362.706665
# 2022-01-06  169.414093  306.557678  154.027466  354.899994
# 2022-01-07  169.581558  306.713989  155.553604  342.320007
# 2022-01-10  169.601242  306.938599  155.702469  352.706665
# ...                ...         ...         ...         ...
# 2022-12-23  130.631378  235.345581  125.269859  123.150002
# 2022-12-27  128.818405  233.600647  125.708817  109.099998
# 2022-12-28  124.865593  231.205109  126.395836  112.709999
# 2022-12-29  128.402313  237.593246  127.121048  121.820000
# 2022-12-30  128.719330  236.420135  127.960762  123.180000
#
# [250 rows x 4 columns]

# %%
Pure_Cum_Returns = pd.concat([AAPL['Cumulative_Pct_Change'],MSFT['Cumulative_Pct_Change'],JPM['Cumulative_Pct_Change'],TSLA['Cumulative_Pct_Change']],axis=1)
Pure_Cum_Returns.columns = ['AAPL','MSFT','JPM','TSLA']

# %%
Pure_Cum_Returns
# Out:
#                  AAPL       MSFT        JPM       TSLA
# Date
# 2022-01-04  -1.269168  -1.714698   3.790955  -4.183270
# 2022-01-05  -3.895403  -5.487680   1.893422  -9.306707
# 2022-01-06  -5.499701  -6.234507   2.975948 -11.258732
# 2022-01-07  -5.406288  -6.186697   3.996257 -14.404306
# 2022-01-10  -5.395308  -6.117996   4.095781 -11.807165
# ...               ...        ...        ...        ...
# 2022-12-23 -27.132955 -28.015848 -16.250115 -69.206854
# 2022-12-27 -28.144244 -28.549564 -15.956648 -72.719999
# 2022-12-28 -30.349148 -29.282277 -15.497337 -71.817333
# 2022-12-29 -28.376342 -27.328364 -15.012492 -69.539416
# 2022-12-30 -28.199508 -27.687179 -14.451096 -69.199353
#
# [250 rows x 4 columns]

# %%
test = np.array([0,1,0,0])

# %%
np.dot(test, Pure_Cum_Returns.transpose())
# Out:
# array([ -1.71469824,  -5.48768029,  -6.23450684,  -6.18669665,
#         -6.11799634,  -5.90589345,  -4.92306825,  -8.94699313,
#         -7.33381455,  -9.58925706,  -9.38611509,  -9.90289827,
#        -11.56684601, -11.46526102, -13.81927356, -11.36371337,
#        -10.42866102,  -7.91336144,  -7.10082154,  -7.76399426,
#         -6.35995959, -10.00747023,  -8.60641319, -10.097098  ,
#         -9.01866175,  -7.03212122,  -9.66989592, -11.86258406,
#        -11.87453194, -10.2404819 , -10.34524988, -12.97052598,
#        -13.80870715, -13.87158287, -16.10170148, -11.81506323,
#        -11.00081516, -10.55778214, -11.70728028, -10.13869156,
#        -11.41690011, -13.23096178, -16.50882552, -17.42483593,
#        -13.63808581, -14.50917033, -16.1615809 , -17.24820331,
#        -14.04219487, -11.87492398, -11.62645474, -10.06685493,
#        -28.17867533, -28.01584812, -28.54956368, -29.2822768 ,
#        -27.32836426, -27.68717872])

# %%
Pure_Returns
# Out:
#                   AAPL        MSFT         JPM        TSLA
# Date
# 2022-01-04  176.998322  321.334778  155.246521  383.196655
# 2022-01-05  172.290176  308.999359  152.408264  362.706665
# 2022-01-06  169.414093  306.557678  154.027466  354.899994
# 2022-01-07  169.581558  306.713989  155.553604  342.320007
# 2022-01-10  169.601242  306.938599  155.702469  352.706665
# ...                ...         ...         ...         ...
# 2022-12-23  130.631378  235.345581  125.269859  123.150002
# 2022-12-27  128.818405  233.600647  125.708817  109.099998
# 2022-12-28  124.865593  231.205109  126.395836  112.709999
# 2022-12-29  128.402313  237.593246  127.121048  121.820000
# 2022-12-30  128.719330  236.420135  127.960762  123.180000
#
# [250 rows x 4 columns]

# %%
log_rets = np.log(Pure_Returns/Pure_Returns.shift(1))

# %%
def gen_weights(N):
    weights = np.random.random(N)
    return weights/np.sum(weights)

# %%
No_Of_Comp = len(Pure_Returns.columns)

# %%
log_rets.mean()
# Out:
# AAPL   -0.001279
# MSFT   -0.001232
# JPM    -0.000776
# TSLA   -0.004558
# dtype: float64

# %%
def calc_rets(weights,log_rets):
    return np.sum(log_rets.mean()*weights) * 252

# %%
log_rets.cov()
# Out:
#           AAPL      MSFT       JPM      TSLA
# AAPL  0.000505  0.000413  0.000233  0.000593
# MSFT  0.000413  0.000498  0.000225  0.000517
# JPM   0.000233  0.000225  0.000348  0.000289
# TSLA  0.000593  0.000517  0.000289  0.001726

# %%
def calc_volatility(weights,log_rets_cov):   ###########################################################################
    annualized_cov = np.dot(log_rets_cov*252,weights)
    vol = np.dot(weights.transpose(),annualized_cov)
    return np.sqrt(vol)

# %%
log_rets_cov = log_rets.cov()

# %%
mc_portfolio_returns = []    
mc_portfolio_vol = []
mc_weights = []

for sim in range(3000):
    
    weights = gen_weights(N=No_Of_Comp)
    mc_weights.append(weights)
    sim_rets = calc_rets(weights,log_rets)
    mc_portfolio_returns.append(sim_rets)
    sim_vol = calc_volatility(weights,log_rets_cov)
    mc_portfolio_vol.append(sim_vol)

# %%
len(mc_portfolio_returns)
# Out:
# 3000

# %%
mc_portfolio_returns
# Out:
# [-0.4039443102727403,
#  -0.5800749655357402,
#  -0.5451081475101242,
#  -0.5692180697280612,
#  -0.4676422073031385,
#  -0.4731766098035978,
#  -0.5098217613623511,
#  -0.3425925395072169,
#  -0.30440143872170383,
#  -0.6509644745298495,
#  -0.6217311430124147,
#  -0.3816437164078208,
#  -0.33246269889800645,
#  -0.5235134814184049,
#  -0.3605886102699992,
#  -0.5709629977199593,
#  -0.4843830320813037,
#  -0.46896183653284956,
#  -0.28007734120652295,
#  -0.5305175437406155,
#  -0.44707147906367084,
#  -0.5570064904823778,
#  -0.3289944714754139,
#  -0.4940523330704186,
#  -0.3677612101840618,
#  -0.3982991105671452,
#  -0.548709984600361,
#  -0.4728869664199219,
#  -0.5920564195884591,
#  -0.6356407597049571,
#  -0.5877201671527197,
#  -0.4214076687987255,
#  -0.3073631311812599,
#  -0.5284916820846461,
#  -0.5874149972624076,
#  -0.4950470075773088,
#  -0.32975321642692307,
#  -0.7017548733540399,
#  -0.6448226044853894,
#  -0.3143187407985586,
#  -0.3961528767106527,
#  -0.41170588730607977,
#  -0.35341797872275965,
#  -0.5764779519714671,
#  -0.3384218538754729,
#  -0.452195716387542,
#  -0.47039151820503733,
#  -0.4902717649218732,
#  -0.38632827563194944,
#  -0.43165601258158137,
#  -0.4548715388468664,
#  -0.5045869766552046,
#  -0.3913215705314326,
#  -0.6299282136182778,
#  -0.5430289541462585,
#  -0.5843098962459902,
#  -0.36651246175905444,
#  -0.5170900006947303,
#  -0.5047921602042559,
#  -0.6554833442079462,
#  -0.5193415937690814,
#  -0.3490280081342451,
#  -0.512367767050905,
#  -0.4075358179120496,
#  ...]

# %%
mc_sharp_ratios = np.array(mc_portfolio_returns)/mc_portfolio_vol

# %%
max_sharpe_idx = np.argmax(mc_sharp_ratios)
max_sharpe_return = mc_portfolio_returns[max_sharpe_idx]
max_sharpe_volatility = mc_portfolio_vol[max_sharpe_idx]
max_sharpe_weights = mc_weights[max_sharpe_idx]

# %%
print("Maximum Sharpe Ratio Portfolio Return:", max_sharpe_return)
print("Maximum Sharpe Ratio Portfolio Volatility:", max_sharpe_volatility)
print("Maximum Sharpe Ratio Portfolio Weights:", max_sharpe_weights)

# Scatterplot
plt.scatter(mc_portfolio_vol, mc_portfolio_returns, c=mc_sharp_ratios, cmap='viridis')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')

plt.scatter(max_sharpe_volatility, max_sharpe_return, c='red', marker='*', s=200)
plt.title('Monte Carlo Simulation of Portfolio Optimization')
plt.show()
# Out:
# Maximum Sharpe Ratio Portfolio Return: -0.24065277443568026
# Maximum Sharpe Ratio Portfolio Volatility: 0.28382659084104217
# Maximum Sharpe Ratio Portfolio Weights: [0.18365063 0.0066767  0.78764341 0.02202926]

# %%
p_weights = max_sharpe_weights

# %%
p_weights
# Out:
# array([0.18365063, 0.0066767 , 0.78764341, 0.02202926])

# %%
values = p_weights
labels = ['AAPL', 'MSFT', 'JPM', 'TSLA']
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
#explode = (0, 0, 0, 0)  # Only "explode" the 1st slice

plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title('Portfolio Holdings')
plt.legend(title="Categories", bbox_to_anchor=(0, 1))
plt.show()

# %%
cum_p_weighted_returns = np.dot(p_weights,Pure_Cum_Returns.transpose())

# %%
cum_p_weighted_returns_perc = cum_p_weighted_returns

# %%
cum_p_weighted_returns_perc
# Out:
# array([  2.64923409,   0.53428859,   1.04431511,   1.79613437,
#          1.93421231,   2.32206401,   2.91634985,   2.31247682,
#         -2.62163425,  -6.24564238,  -7.81516686,  -8.61334825,
#        -10.19675586, -10.36501164,  -9.81347372,  -9.09011877,
#        -20.80394252, -21.02543405, -19.13612378, -19.49269886,
#        -18.63103505, -19.88029174, -20.39776406, -18.70541033,
#        -18.34810992, -18.27887987, -19.6922659 , -15.68179715,
#        -15.24682951, -16.1282019 , -16.41702717, -16.49386592,
#        -16.61019214, -15.91648162, -16.71249523, -15.47512115,
#        -14.58288588, -14.75469333, -16.36158279, -15.57505217,
#        -13.95862389, -14.90592155, -15.49778147, -17.5999866 ,
#        -17.89168588, -18.17018462, -17.30043804, -17.68502115,
#        -16.4660693 , -16.46089889, -17.04917329, -19.40508012,
#        -20.06372944, -19.90452614, -19.65883173, -18.59647865,
#        -19.75686429, -19.49390941, -19.52944094, -19.55760705,
#        -18.75018873, -18.27043784])

# %%
cpwrp_Fin = Pure_Cum_Returns.assign(cum_change=cum_p_weighted_returns_perc)

# %%
cpwrp_Fin
# Out:
#                  AAPL       MSFT        JPM       TSLA  cum_change
# Date
# 2022-01-04  -1.269168  -1.714698   3.790955  -4.183270    2.649234
# 2022-01-05  -3.895403  -5.487680   1.893422  -9.306707    0.534289
# 2022-01-06  -5.499701  -6.234507   2.975948 -11.258732    1.044315
# 2022-01-07  -5.406288  -6.186697   3.996257 -14.404306    1.796134
# 2022-01-10  -5.395308  -6.117996   4.095781 -11.807165    1.934212
# ...               ...        ...        ...        ...         ...
# 2022-12-23 -27.132955 -28.015848 -16.250115 -69.206854  -19.493909
# 2022-12-27 -28.144244 -28.549564 -15.956648 -72.719999  -19.529441
# 2022-12-28 -30.349148 -29.282277 -15.497337 -71.817333  -19.557607
# 2022-12-29 -28.376342 -27.328364 -15.012492 -69.539416  -18.750189
# 2022-12-30 -28.199508 -27.687179 -14.451096 -69.199353  -18.270438
#
# [250 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(10,5),dpi=200)

ax.plot(cpwrp_Fin['AAPL'], label='AAPL')
ax.plot(cpwrp_Fin['MSFT'], label='MSFT')
ax.plot(cpwrp_Fin['JPM'], label='JPM')
ax.plot(cpwrp_Fin['TSLA'], label='TSLA')
ax.plot(cpwrp_Fin['cum_change'], label='Optimum weight')

fig.patch.set_facecolor('#1e1e1e')

ax.set_facecolor('#2b2b2b')
ax.grid(color='gray', linestyle='--', linewidth=0.5)
# Visual theme
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')

ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
ax.set_xlabel('Time Series', color='white')
ax.set_ylabel('Price', color='white')
ax.set_title('Plotting Price Change Charts', color='white')

legend = ax.legend()
frame = legend.get_frame()
frame.set_facecolor('#1e1e1e')  # Set the legend background color
frame.set_edgecolor('white')  # Set the legend border color
for text in legend.get_texts():
    text.set_color('white')  # Set the legend text color

# Ensure equal aspect ratio
ax.axis('auto')

plt.show()

# %%
print(cpwrp_Fin['AAPL'].std())
print(cpwrp_Fin['MSFT'].std())
print(cpwrp_Fin['JPM'].std())
print(cpwrp_Fin['TSLA'].std())
print(cpwrp_Fin['cum_change'].std())
# Out:
# 7.0514067763187995
# 7.457018121400148
# 8.674649874355104
# 14.321381283842683
# 7.6944736608584705

# %%
##############################################################################################################
                          #""""           Check For 2023         """#
##############################################################################################################

# %%
ticker_symbol = 'AAPL'
stock_data = yf.download(ticker_symbol, start = '2023-01-01', end = '2023-12-31')
AAPL = pd.DataFrame(stock_data)
AAPL = AAPL.drop(columns=['Volume','Open', 'High', 'Low', 'Close'])

ticker_symbol = 'MSFT'
stock_data = yf.download(ticker_symbol, start = '2023-01-01', end = '2023-12-31')
MSFT = pd.DataFrame(stock_data)
MSFT = MSFT.drop(columns=['Volume','Open', 'High', 'Low', 'Close'])

ticker_symbol = 'JPM'
stock_data = yf.download(ticker_symbol, start = '2023-01-01', end = '2023-12-31')
JPM = pd.DataFrame(stock_data)
JPM = JPM.drop(columns=['Volume','Open', 'High', 'Low', 'Close'])

ticker_symbol = 'TSLA'
stock_data = yf.download(ticker_symbol, start = '2023-01-01', end = '2023-12-31')
TSLA = pd.DataFrame(stock_data)
TSLA = TSLA.drop(columns=['Volume','Open', 'High', 'Low', 'Close'])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
AAPL
# Out:
#              Adj Close
# Date
# 2023-01-03  123.904625
# 2023-01-04  125.182610
# 2023-01-05  123.855103
# 2023-01-06  128.412247
# 2023-01-09  128.937302
# ...                ...
# 2023-12-22  192.868134
# 2023-12-26  192.320221
# 2023-12-27  192.419830
# 2023-12-28  192.848206
# 2023-12-29  191.802170
#
# [250 rows x 1 columns]

# %%
AAPL['Percentage Change'] = AAPL['Adj Close'].pct_change()
AAPL['Cumulative Percentage Change'] = AAPL['Percentage Change'].cumsum()

MSFT['Percentage Change'] = MSFT['Adj Close'].pct_change()
MSFT['Cumulative Percentage Change'] = MSFT['Percentage Change'].cumsum()

JPM['Percentage Change'] = JPM['Adj Close'].pct_change()
JPM['Cumulative Percentage Change'] = JPM['Percentage Change'].cumsum()

TSLA['Percentage Change'] = TSLA['Adj Close'].pct_change()
TSLA['Cumulative Percentage Change'] = TSLA['Percentage Change'].cumsum()

# %%
AAPL = AAPL.dropna()
MSFT = MSFT.dropna()
JPM = JPM.dropna()
TSLA = TSLA.dropna()

# %%
fig, ax = plt.subplots(figsize=(10,5),dpi=200)

ax.plot(AAPL['Cumulative Percentage Change'], label='AAPL')
ax.plot(MSFT['Cumulative Percentage Change'], label='MSFT')
ax.plot(JPM['Cumulative Percentage Change'], label='JPM')
ax.plot(TSLA['Cumulative Percentage Change'], label='TSLA')


# Customize the background color of the figure and axis
fig.patch.set_facecolor('#1e1e1e')
ax.set_facecolor('#2b2b2b')

# Customize the gridlines
ax.grid(color='gray', linestyle='--', linewidth=0.5)

# Customize the spines (axis borders)
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')

# Customize the ticks
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Customize the labels and title
ax.set_xlabel('Time Series', color='white')
ax.set_ylabel('Price', color='white')
ax.set_title('Plotting Price Change Charts', color='white')

# Customize the legend
legend = ax.legend()
frame = legend.get_frame()
frame.set_facecolor('#1e1e1e')  # Set the legend background color
frame.set_edgecolor('white')  # Set the legend border color
for text in legend.get_texts():
    text.set_color('white')  # Set the legend text color

# Ensure equal aspect ratio
ax.axis('auto')

plt.show()

# %%
company_returns = pd.concat([AAPL['Cumulative Percentage Change'],MSFT['Cumulative Percentage Change'],JPM['Cumulative Percentage Change'],TSLA['Cumulative Percentage Change']],axis=1)
company_returns.columns = ['AAPL','MSFT','JPM','TSLA']

# %%
company_returns
# Out:
#                 AAPL      MSFT       JPM      TSLA
# Date
# 2023-01-04  0.010314 -0.043743  0.009325  0.051249
# 2023-01-05 -0.000290 -0.073381  0.009104  0.022210
# 2023-01-06  0.036504 -0.061596  0.028239  0.046861
# 2023-01-09  0.040593 -0.051859  0.024107  0.106210
# 2023-01-10  0.045049 -0.044242  0.033061  0.098528
# ...              ...       ...       ...       ...
# 2023-12-22  0.462418  0.487045  0.264897  0.984507
# 2023-12-26  0.459577  0.487258  0.270811  1.000624
# 2023-12-27  0.460095  0.485684  0.276809  1.019446
# 2023-12-28  0.462321  0.488918  0.282122  0.987852
# 2023-12-29  0.456897  0.490944  0.280947  0.969288
#
# [249 rows x 4 columns]

# %%
company_returns['AAPL'] = company_returns['AAPL'] * 100
company_returns['MSFT'] = company_returns['MSFT'] * 100
company_returns['JPM'] = company_returns['JPM'] * 100
company_returns['TSLA'] = company_returns['TSLA'] * 100

# %%
p_weights #= [0.02881366, 0.14686726, 0.81186321, 0.01245586]
# Out:
# array([0.18365063, 0.0066767 , 0.78764341, 0.02202926])

# %%
cum_p_weighted_returns = np.dot(p_weights,company_returns.transpose())

# %%
cum_p_weighted_returns
# Out:
# array([ 1.007604  ,  0.7116366 ,  2.95672061,  2.84358757,  3.61885033,
#         4.69309726,  4.61695291,  6.77172156,  5.8820622 ,  3.35916748,
#         2.27912635,  2.95713793,  4.84283147,  5.70536445,  6.00452424,
#         7.02539593,  7.71076821,  6.52022189,  7.25651323,  7.31085812,
#         7.73936099,  9.41051818,  9.5959508 , 10.96076107, 10.13085461,
#         8.83626045,  9.11700845, 10.31251228, 10.75041457, 11.38295912,
#         9.96368801, 10.11631249,  8.05142425,  7.53690502,  8.2502463 ,
#         8.55901623,  9.5207178 , 10.09438532,  9.35327852,  8.49550447,
#        10.67664815, 10.51639056,  7.85747661,  7.47721345,  2.82574422,
#         4.56783233,  3.42459111,  5.83463408,  2.13974183,  4.08415832,
#         0.96808468,  2.10604505,  4.61399354,  2.33827123,  2.28120431,
#         1.22150583,  3.25940346,  3.39250481,  3.98227577,  3.95037473,
#         5.33941842,  5.25298062,  4.11546544,  3.9382053 ,  3.96431411,
#         3.91889842,  4.17957617,  4.01521023,  5.02223989, 10.91169345,
#        11.56894915, 12.55797329, 12.54140641, 11.98526439, 11.68203516,
#        11.77993083,  9.85348971,  8.40986499, 10.10506158, 10.98943482,
#        12.62926074, 11.22271088,  9.43893138,  8.18979388, 10.72280585,
#        10.9235904 , 10.32378041, 10.5591783 , 10.37268797,  9.08932924,
#         9.67952284,  9.15668218, 11.74805226, 12.6443853 , 12.51533729,
#        11.87659277, 10.72809361, 10.00023574, 10.35979378, 11.47430426,
#        12.05689895, 11.07363323, 12.50050991, 14.31685266, 13.4425764 ,
#        13.57927333, 14.21178749, 14.6230144 , 14.91200381, 15.25292517,
#        15.85794297, 15.61788012, 16.72788003, 16.74272043, 16.45957052,
#        16.11010593, 14.95323908, 14.43396073, 14.3418311 , 14.71987448,
#        14.54658014, 17.33951043, 18.91505595, 19.55260051, 18.94134199,
#        18.16853109, 18.6571084 , 18.85036688, 20.03332765, 20.61583365,
#        21.13181508, 21.65506816, 23.94279734, 24.11099785, 24.51948884,
#        25.07430373, 24.32575321, 26.03281247, 25.50788099, 26.03061908,
#        24.95510729, 25.76035629, 26.34893477, 25.82990286, 24.57718195,
#        24.9676834 , 23.87545525, 23.91599493, 23.54784224, 22.2532601 ,
#        22.142898  , 22.57747363, 22.89324104, 20.61545306, 20.11896297,
#        18.96389023, 19.15746602, 19.74200392, 18.2731306 , 19.25298732,
#        18.6197484 , 18.84381019, 19.28306005, 20.50320559, 20.53599452,
#        19.59269748, 19.90215747, 19.16948964, 18.34136939, 17.12071702,
#        17.22776951, 17.9240502 , 18.57446162, 18.43451796, 20.16737502,
#        19.82900433, 20.22820939, 20.25065785, 19.50199688, 18.6622608 ,
#        17.89980497, 18.44459844, 17.1604364 , 17.42769379, 18.48932436,
#        17.21256748, 16.83106632, 16.04581799, 16.67585857, 17.13162029,
#        18.63571694, 18.60973149, 19.05755406, 19.47604069, 19.34870303,
#        20.26982952, 20.21121616, 19.88631386, 18.77648844, 18.19968102,
#        16.57044208, 15.51510905, 15.70535481, 15.00673309, 14.66268613,
#        11.99245594, 13.13221668, 14.16440503, 14.5091608 , 16.43707212,
#        17.24510525, 18.10835231, 18.3721943 , 18.87284624, 18.46569685,
#        20.12591784, 19.70622485, 21.54722761, 22.34352301, 23.3368867 ,
#        24.04292451, 24.48147882, 24.2839858 , 24.47861568, 24.46876943,
#        24.27980164, 24.62528305, 24.8963231 , 25.81433344, 26.30335476,
#        26.66751953, 27.0798526 , 26.14704914, 26.60911569, 27.63112079,
#        27.63963778, 28.46852723, 29.06120196, 30.60122056, 31.17697638,
#        31.48862756, 32.68497224, 31.50876346, 32.01475202, 31.8507422 ,
#        32.30002717, 32.82237338, 33.21428453, 32.98263339])

# %%
cpwrp_Fin = company_returns.assign(cum_change=cum_p_weighted_returns)

# %%
fig, ax = plt.subplots(figsize=(10,5),dpi=200)

ax.plot(cpwrp_Fin['cum_change'], label='Portfolio Change')

# Customize the background color of the figure and axis
fig.patch.set_facecolor('#1e1e1e')
ax.set_facecolor('#2b2b2b')

# Customize the gridlines
ax.grid(color='gray', linestyle='--', linewidth=0.5)

# Customize the spines (axis borders)
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')

# Customize the ticks
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Customize the labels and title
ax.set_xlabel('Time Series', color='white')
ax.set_ylabel('Price Percentage', color='white')
ax.set_title('Portfolio Change', color='white')

# Customize the legend
legend = ax.legend()
frame = legend.get_frame()
frame.set_facecolor('#1e1e1e')  # Set the legend background color
frame.set_edgecolor('white')  # Set the legend border color
for text in legend.get_texts():
    text.set_color('white')  # Set the legend text color

# Ensure equal aspect ratio
ax.axis('auto')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(7,5),dpi=200)

ax.plot(company_returns['AAPL'], label='AAPL')
ax.plot(cpwrp_Fin['cum_change'], label='Portfolio Change')

# Customize the background color of the figure and axis
fig.patch.set_facecolor('#1e1e1e')
ax.set_facecolor('#2b2b2b')

# Customize the gridlines
ax.grid(color='gray', linestyle='--', linewidth=0.5)

# Customize the spines (axis borders)
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')

# Customize the ticks
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Customize the labels and title
ax.set_xlabel('Time Series', color='white')
ax.set_ylabel('Price Percentage', color='white')
ax.set_title('Portfolio Change', color='white')

# Customize the legend
legend = ax.legend()
frame = legend.get_frame()
frame.set_facecolor('#1e1e1e')  # Set the legend background color
frame.set_edgecolor('white')  # Set the legend border color
for text in legend.get_texts():
    text.set_color('white')  # Set the legend text color

# Ensure equal aspect ratio
ax.axis('auto')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(7,5),dpi=200)

ax.plot(company_returns['MSFT'], label='MSFT')
ax.plot(cpwrp_Fin['cum_change'], label='Portfolio Change')

# Customize the background color of the figure and axis
fig.patch.set_facecolor('#1e1e1e')
ax.set_facecolor('#2b2b2b')

# Customize the gridlines
ax.grid(color='gray', linestyle='--', linewidth=0.5)

# Customize the spines (axis borders)
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')

# Customize the ticks
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Customize the labels and title
ax.set_xlabel('Time Series', color='white')
ax.set_ylabel('Price Percentage', color='white')
ax.set_title('Portfolio Change', color='white')

# Customize the legend
legend = ax.legend()
frame = legend.get_frame()
frame.set_facecolor('#1e1e1e')  # Set the legend background color
frame.set_edgecolor('white')  # Set the legend border color
for text in legend.get_texts():
    text.set_color('white')  # Set the legend text color

# Ensure equal aspect ratio
ax.axis('auto')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(7,5),dpi=200)

ax.plot(company_returns['JPM'], label='JPM')
ax.plot(cpwrp_Fin['cum_change'], label='Portfolio Change')

# Customize the background color of the figure and axis
fig.patch.set_facecolor('#1e1e1e')
ax.set_facecolor('#2b2b2b')

# Customize the gridlines
ax.grid(color='gray', linestyle='--', linewidth=0.5)

# Customize the spines (axis borders)
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')

# Customize the ticks
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Customize the labels and title
ax.set_xlabel('Time Series', color='white')
ax.set_ylabel('Price Percentage', color='white')
ax.set_title('Portfolio Change', color='white')

# Customize the legend
legend = ax.legend()
frame = legend.get_frame()
frame.set_facecolor('#1e1e1e')  # Set the legend background color
frame.set_edgecolor('white')  # Set the legend border color
for text in legend.get_texts():
    text.set_color('white')  # Set the legend text color

# Ensure equal aspect ratio
ax.axis('auto')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(7,5),dpi=200)

ax.plot(company_returns['TSLA'], label='TSLA')
ax.plot(cpwrp_Fin['cum_change'], label='Portfolio Change')

# Customize the background color of the figure and axis
fig.patch.set_facecolor('#1e1e1e')
ax.set_facecolor('#2b2b2b')

# Customize the gridlines
ax.grid(color='gray', linestyle='--', linewidth=0.5)

# Customize the spines (axis borders)
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')

# Customize the ticks
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Customize the labels and title
ax.set_xlabel('Time Series', color='white')
ax.set_ylabel('Price Percentage', color='white')
ax.set_title('Portfolio Change', color='white')

# Customize the legend
legend = ax.legend()
frame = legend.get_frame()
frame.set_facecolor('#1e1e1e')  # Set the legend background color
frame.set_edgecolor('white')  # Set the legend border color
for text in legend.get_texts():
    text.set_color('white')  # Set the legend text color

# Ensure equal aspect ratio
ax.axis('auto')

plt.show()

# %%
cpwrp_Fin
# Out:
#                  AAPL       MSFT        JPM        TSLA  cum_change
# Date
# 2023-01-04   1.031426  -4.374319   0.932517    5.124885    1.007604
# 2023-01-05  -0.029030  -7.338091   0.910356    2.220976    0.711637
# 2023-01-06   3.650385  -6.159557   2.823892    4.686085    2.956721
# 2023-01-09   4.059268  -5.185922   2.410676   10.620986    2.843588
# 2023-01-10   4.504899  -4.424210   3.306079    9.852848    3.618850
# ...               ...        ...        ...         ...         ...
# 2023-12-22  46.241772  48.704492  26.489690   98.450743   31.850742
# 2023-12-26  45.957685  48.725847  27.081089  100.062366   32.300027
# 2023-12-27  46.009479  48.568371  27.680880  101.944606   32.822373
# 2023-12-28  46.232104  48.891834  28.212169   98.785178   33.214285
# 2023-12-29  45.689690  49.094355  28.094738   96.928792   32.982633
#
# [249 rows x 5 columns]

# %%
print(cpwrp_Fin['AAPL'].std())
print(cpwrp_Fin['MSFT'].std())
print(cpwrp_Fin['JPM'].std())
print(cpwrp_Fin['TSLA'].std())
print(cpwrp_Fin['cum_change'].std())
# Out:
# 10.960960996443566
# 14.611666220829763
# 7.375151296110788
# 23.70095021431387
# 7.891403923525385
